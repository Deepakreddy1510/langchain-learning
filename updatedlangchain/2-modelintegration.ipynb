# %% [markdown]
# ### Models integration With OpenAI, Google Gemini and GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    "llama-3.3-70b-versatile",
    model_provider="groq"
)

model
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.5.5', 'langchain': '1.3.15'}}, profile={'name': 'Llama 3.3 70B Versatile', 'release_date': '2024-12-06', 'last_updated': '2024-12-06', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x000001F0DB8B3620>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001F0DBACC1A0>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
## invoke the model
response = model.invoke("Hello How are you")
response
# Out:
# AIMessage(content="Hello. I'm doing well, thanks for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm always happy to chat and help with any questions or topics you'd like to discuss. How about you? How's your day going so far?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 63, 'prompt_tokens': 39, 'total_tokens': 102, 'completion_time': 0.11508178, 'completion_tokens_details': None, 'prompt_time': 0.00170769, 'prompt_tokens_details': None, 'queue_time': 0.050642695, 'total_time': 0.11678947}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a00a1f-63fb-7f82-a1f6-48e911b227ee-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 63, 'total_tokens': 102})

# %%
response.content
# Out:
# "Hello. I'm doing well, thanks for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm always happy to chat and help with any questions or topics you'd like to discuss. How about you? How's your day going so far?"

# %% [markdown]
# ### Google Gemini Model Integration

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGlE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model = init_chat_model("google_genai:gemini-3.5-flash-lite")
response = model.invoke("Why do parrots talk")
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Parrots talk primarily because of their **social nature** and their **brains\' unique evolutionary adaptations**. In the wild, talking—or more accurately, mimicking—is a tool for survival and community building. \n\nHere is a breakdown of why parrots talk:\n\n### 1. They are "Flock" Animals\nIn the wild, parrots live in large, noisy groups. To survive, individuals need to communicate constantly with their flock members to signal danger, find food, and maintain social bonds. A parrot’s family is its whole world, and vocalizing is how they stay connected.\n\n### 2. Desire to Fit In (Social Integration)\nParrots are hardwired to copy the sounds of those around them. In the wild, a baby parrot learns the specific "dialect" of its parents and flock. If a parrot doesn\'t sound like the rest of the flock, it risks being ostracized. When kept as pets, humans become their "flock," so parrots mimic human speech to fit in and bond with their human family.\n\n### 3. High Intelligence and Brain Structure\nParrots (along with corvids like crows and ravens) have exceptionally large brains relative to their body size, particularly an area of the brain called the **song system**, which is dedicated to learning and producing sounds. They also possess a unique organ called the **syrinx** (located at the bottom of the trachea), which allows them to modulate airflow and replicate complex sounds—including human words, microwave beeps, and doorbells—far better than most other birds.\n\n### 4. Attention and Reinforcement\nPets quickly learn that talking gets results. If a parrot squawks "Hello!" or says "Want a cracker?" and suddenly gets a reaction (laughter, attention, or food), their brain registers that sound as a high-value tool. They realize: *When I make this noise, good things happen.*\n\n### 5. Boredom and Self-Amusement\nParrots are intelligent animals that require a lot of mental stimulation. If they are bored, they may practice talking simply to entertain themselves, much like a human humming or singing a song when alone.\n\n---\n\n### Do they actually understand what they are saying?\nUsually, **no**. Parrots are generally mimicking sounds without understanding the dictionary definition of the words. To them, "Want a peanut?" doesn\'t mean "I am hungry," but rather, "This specific sound usually results in me getting a peanut."\n\nHowever, famous scientific studies—such as the decades-long research by Dr. Irene Pepperberg with an African Grey parrot named **Alex**—proved that parrots *can* learn the conceptual meaning of words. Alex could correctly identify colors, shapes, and numbers, proving that parrots are capable of genuine, context-based communication, not just mindless repetition.', 'extras': {'signature': 'El4KXAERTTIPgB6WTbPTq7u67njnyfUrbpD35jQh04Frlu28nP5GCu8x/qsUYUGyoXHwQMKLvDz0buyVFjku/6sruG9Z9GdaqXG/2mx7nWG4UN0FH/0S/dZBb4jQ+qYd'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a00a28-268d-7d93-9823-1f5439fa4f02-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 5, 'output_tokens': 585, 'total_tokens': 590, 'input_token_details': {'cache_read': 0}})
